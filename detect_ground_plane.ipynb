# %%
import open3d as o3d
# o3d.visualization.webrtc_server.enable_webrtc()
from open3d.web_visualizer import draw
import numpy as np
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [Open3D INFO] Resetting default logger to print to terminal.

# %%
def quat_from_two_vectors_wxyz(a, b):
    # quaternion rotate one vec to another
    a /= np.linalg.norm(a)
    b /= np.linalg.norm(b)

    v = np.cross(a, b)
    w = 1.0 + np.dot(a, b)

    q = np.array([w, v[0], v[1], v[2]], dtype=float)
    q /= np.linalg.norm(q)
    return q

# %%
import numpy as np
import open3d as o3d

pcd = o3d.io.read_point_cloud("/home/roman/ba/huk_scenes/audi_nbg/sparse/0/points3D.ply")
# pcd = o3d.io.read_point_cloud("/home/roman/ba/datasets/ref_real/sedan/sparse/0/points3D.ply")

pcd_filtered = pcd.voxel_down_sample(voxel_size=0.10)
pcd_filtered, _ = pcd_filtered.remove_statistical_outlier(nb_neighbors=30, std_ratio=2.0)

plane_model, inliers = pcd.segment_plane(
    distance_threshold=0.08,
    ransac_n=3,
    num_iterations=2000
)

[a, b, c, d] = plane_model
print("Plane:", plane_model, "inliers:", len(inliers))

n = np.array([a,b,c], float)

z_axis = np.array([0.0, 0.0, 1.0])

q_wxyz = quat_from_two_vectors_wxyz(n, z_axis)
R = o3d.geometry.get_rotation_matrix_from_quaternion(q_wxyz)

pcd.rotate(R, center=pcd.get_center())
o3d.io.write_point_cloud("audi_nbg_rotated.ply", pcd)
draw(pcd)
# Out:
# Plane: [-0.03306963  0.93876352  0.34297152 -1.69238756] inliers: 92226
# [Open3D INFO] Window window_11 created.
# WebVisualizer(window_uid='window_11')

# %%
from dataclasses import dataclass
from typing import List, Tuple
import struct

@dataclass
class Point3D:
    id: int
    xyz: Tuple[float, float, float]  # Assuming xyz is a tuple of three floats
    rgb: Tuple[int, int, int]  # Assuming rgb is a tuple of three integers representing color
    error: float
    image_ids: List[int]  # Assuming image_ids is a list of integers
    point2D_idxs: List[int]  # Assuming point2D_idxs is a list of integers

def read_next_bytes(fid, num_bytes, format_char_sequence, endian_character="<"):
    """Read and unpack the next bytes from a binary file.
    :param fid:
    :param num_bytes: Sum of combination of {2, 4, 8}, e.g. 2, 6, 16, 30, etc.
    :param format_char_sequence: List of {c, e, f, d, h, H, i, I, l, L, q, Q}.
    :param endian_character: Any of {@, =, <, >, !}
    :return: Tuple of read and unpacked values.
    """
    data = fid.read(num_bytes)
    return struct.unpack(endian_character + format_char_sequence, data)

# %%
def read_points3D_binary(path_to_model_file):
    """
    see: src/base/reconstruction.cc
        void Reconstruction::ReadPoints3DBinary(const std::string& path)
        void Reconstruction::WritePoints3DBinary(const std::string& path)
    """
    points3D = {}
    with open(path_to_model_file, "rb") as fid:
        num_points = read_next_bytes(fid, 8, "Q")[0]
        for point_line_index in range(num_points):
            binary_point_line_properties = read_next_bytes(
                fid, num_bytes=43, format_char_sequence="QdddBBBd")
            point3D_id = binary_point_line_properties[0]
            xyz = np.array(binary_point_line_properties[1:4])
            rgb = np.array(binary_point_line_properties[4:7])
            error = np.array(binary_point_line_properties[7])
            track_length = read_next_bytes(
                fid, num_bytes=8, format_char_sequence="Q")[0]
            track_elems = read_next_bytes(
                fid, num_bytes=8 * track_length,
                format_char_sequence="ii" * track_length)
            image_ids = np.array(tuple(map(int, track_elems[0::2])))
            point2D_idxs = np.array(tuple(map(int, track_elems[1::2])))
            points3D[point3D_id] = Point3D(
                id=point3D_id, xyz=xyz, rgb=rgb,
                error=error, image_ids=image_ids,
                point2D_idxs=point2D_idxs)
    return points3D

# %%
def read_points3D_bin(path: str):
    """
    COLMAP points3D.bin format (little-endian):
      Q            : num_points
      repeat num_points:
        Q          : point3D_id
        d d d      : xyz
        B B B      : rgb
        d          : error
        Q          : track_length
        repeat track_length:
          I I      : image_id, point2D_idx   (ignored here)
    """
    with open(path, "rb") as f:
        num_points = struct.unpack("<Q", f.read(8))[0]

        xyz = np.empty((num_points, 3), dtype=np.float64)
        rgb = np.empty((num_points, 3), dtype=np.uint8)

        for i in range(num_points):
            _pid = struct.unpack("<Q", f.read(8))[0]
            x, y, z = struct.unpack("<ddd", f.read(24))
            r, g, b = struct.unpack("<BBB", f.read(3))
            _err = struct.unpack("<d", f.read(8))[0]

            track_len = struct.unpack("<Q", f.read(8))[0]
            f.seek(track_len * 8, 1)  # each track elem = 2*uint32 = 8 bytes

            xyz[i] = (x, y, z)
            rgb[i] = (r, g, b)

    return xyz, rgb

def write_ply_ascii(path: str, xyz: np.ndarray, rgb: np.ndarray):
    n = xyz.shape[0]
    with open(path, "w", encoding="utf-8") as f:
        f.write("ply\n")
        f.write("format ascii 1.0\n")
        f.write(f"element vertex {n}\n")
        f.write("property float x\nproperty float y\nproperty float z\n")
        f.write("property uchar red\nproperty uchar green\nproperty uchar blue\n")
        f.write("end_header\n")
        for (x, y, z), (r, g, b) in zip(xyz, rgb):
            f.write(f"{x:.6f} {y:.6f} {z:.6f} {int(r)} {int(g)} {int(b)}\n")

# %%
xyz, rgb = read_points3D_bin("/home/roman/ba/huk_scenes_stablenormal/audi_silver/sparse/0/points3D.bin")
write_ply_ascii("/home/roman/ba/huk_scenes_stablenormal/audi_silver/sparse/0/points3D.ply", xyz, rgb)
# Out:
# [5287:440][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:727][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:759][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:775][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:799][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:804][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:808][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:814][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:922][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.
# [5288:958][3461] (dtls_transport.cc:529): DtlsTransport[0|1|__]: OnWritableState() called in state DTLS_TRANSPORT_CLOSED.

# %%
points = read_points3D_binary("/home/roman/ba/huk_scenes_stablenormal/audi_silver/sparse/0/points3D.bin")

# %%
vals = list(points.values())

# %%
vals
# Out:
# [Point3D(id=4, xyz=array([ 4.31974276, -1.85006096,  1.42762857]), rgb=array([55, 65, 32]), error=array(2.73133126), image_ids=array([149, 150,   1]), point2D_idxs=array([ 63, 129,   3])),
#  Point3D(id=7, xyz=array([ 1.45469431, -2.31287665,  3.02735   ]), rgb=array([ 88, 102,  49]), error=array(1.91518441), image_ids=array([  2,   1, 149, 150, 151]), point2D_idxs=array([    6,     6,  3704,  4033, 17273])),
#  Point3D(id=8, xyz=array([ 1.57925506, -2.30973327,  2.99266066]), rgb=array([76, 88, 44]), error=array(0.91515727), image_ids=array([  2,   1, 153]), point2D_idxs=array([    7,     7, 15447])),
#  Point3D(id=9, xyz=array([ 1.59957438, -2.17880266,  2.73618758]), rgb=array([55, 68, 20]), error=array(2.08015372), image_ids=array([2, 1]), point2D_idxs=array([8, 8])),
#  Point3D(id=10, xyz=array([ 1.6742141 , -2.1187703 ,  2.60749175]), rgb=array([69, 76, 36]), error=array(2.33544069), image_ids=array([2, 1]), point2D_idxs=array([9, 9])),
#  Point3D(id=11, xyz=array([ 1.86354553, -2.19119466,  2.71705015]), rgb=array([81, 92, 42]), error=array(1.46606936), image_ids=array([  2,   1,   3, 150]), point2D_idxs=array([  10,   10, 1880, 4037])),
#  Point3D(id=12, xyz=array([ 1.82673009, -2.00979557,  2.37265199]), rgb=array([61, 74, 30]), error=array(2.33459681), image_ids=array([  2, 155, 156, 148, 151]), point2D_idxs=array([   11, 15500, 13633,  3265,   669])),
#  Point3D(id=13, xyz=array([ 2.17273697, -2.22405887,  2.71681424]), rgb=array([72, 82, 35]), error=array(1.62057147), image_ids=array([148,   2, 147, 150]), point2D_idxs=array([  142, 31547, 18577,  4031])),
#  Point3D(id=14, xyz=array([ 4.05729469, -3.46889595,  4.71987775]), rgb=array([76, 86, 15]), error=array(2.2302302), image_ids=array([2, 1]), point2D_idxs=array([13, 13])),
#  Point3D(id=16, xyz=array([ 3.95303103, -2.91262006,  3.69993657]), rgb=array([80, 92, 37]), error=array(0.63255534), image_ids=array([2, 1]), point2D_idxs=array([15, 15])),
#  Point3D(id=19, xyz=array([ 3.56505639, -2.23208423,  2.48965401]), rgb=array([55, 64,  0]), error=array(0.73083395), image_ids=array([2, 1]), point2D_idxs=array([18, 18])),
#  Point3D(id=20, xyz=array([ 3.28666689, -1.73005968,  1.59671538]), rgb=array([77, 92, 23]), error=array(1.3141916), image_ids=array([2, 1]), point2D_idxs=array([19, 19])),
#  Point3D(id=22, xyz=array([ 3.43904785, -1.74984757,  1.5951461 ]), rgb=array([85, 99, 44]), error=array(2.47174705), image_ids=array([2, 1]), point2D_idxs=array([21, 21])),
#  Point3D(id=24, xyz=array([ 5.28984639, -2.63021388,  2.93964819]), rgb=array([92, 98, 65]), error=array(1.0947293), image_ids=array([2, 1]), point2D_idxs=array([23, 23])),
#  Point3D(id=25, xyz=array([ 5.04329446, -2.37343064,  2.50754061]), rgb=array([75, 85, 44]), error=array(1.92394096), image_ids=array([  2,   1, 150]), point2D_idxs=array([  24,   24, 4015])),
#  Point3D(id=27, xyz=array([ 1.57930663, -2.33906697,  3.07146797]), rgb=array([ 85, 100,  48]), error=array(2.46402684), image_ids=array([149, 150, 154, 157,   1, 143, 147, 148, 155]), point2D_idxs=array([  174,   219,    27,    26,    26, 25981, 20907, 19868,    26])),
#  Point3D(id=35, xyz=array([ 1.46466638, -2.35149703,  3.14429207]), rgb=array([137, 154, 102]), error=array(2.28565247), image_ids=array([  2,   3, 149, 150]), point2D_idxs=array([   34,     0,   183, 40680])),
#  Point3D(id=36, xyz=array([ 1.69104461, -2.08427947,  2.55984402]), rgb=array([133, 153, 118]), error=array(1.64425423), image_ids=array([144,   1, 147, 150]), point2D_idxs=array([ 99,  35,  80, 223])),
#  Point3D(id=38, xyz=array([ 4.70409801, -2.32977285,  2.53699266]), rgb=array([147, 139, 114]), error=array(0.90760497), image_ids=array([  2,   3,   1, 150]), point2D_idxs=array([   37, 29161,    37,   190])),
#  Point3D(id=39, xyz=array([ 5.00922263, -2.42313849,  2.67312502]), rgb=array([110, 114,  76]), error=array(0.90601795), image_ids=array([  2, 150,   1, 147, 149]), point2D_idxs=array([ 38, 191,  38,  45, 117])),
#  Point3D(id=40, xyz=array([ 5.18419442, -2.42405518,  2.64730305]), rgb=array([85, 90, 52]), error=array(2.49114608), image_ids=array([  2, 149, 150,   1]), point2D_idxs=array([ 39, 118, 192,  39])),
#  Point3D(id=42, xyz=array([ 3.52479164, -2.74663339,  3.53117357]), rgb=array([236, 236, 206]), error=array(1.90701097), image_ids=array([144, 147,   1]), point2D_idxs=array([106,  71,  41])),
#  Point3D(id=45, xyz=array([ 1.54760526, -2.34539294,  3.29745611]), rgb=array([129, 139, 102]), error=array(1.89403342), image_ids=array([  2,   1, 200]), point2D_idxs=array([  45,   45, 1678])),
#  Point3D(id=49, xyz=array([ 2.0559192 , -2.30392405,  3.13295135]), rgb=array([54, 61, 34]), error=array(2.06484309), image_ids=array([2, 1]), point2D_idxs=array([49, 49])),
#  Point3D(id=50, xyz=array([ 2.2797812 , -2.3939291 ,  3.27154386]), rgb=array([150, 155, 129]), error=array(1.39542229), image_ids=array([2, 1]), point2D_idxs=array([50, 50])),
#  Point3D(id=51, xyz=array([ 2.27621961, -2.24544686,  2.97990046]), rgb=array([55, 67, 12]), error=array(2.09899034), image_ids=array([2, 1]), point2D_idxs=array([51, 51])),
#  Point3D(id=52, xyz=array([ 2.49505066, -2.31860078,  3.09287103]), rgb=array([67, 78, 35]), error=array(1.16680863), image_ids=array([2, 1, 3]), point2D_idxs=array([  52,   52, 1924])),
#  Point3D(id=53, xyz=array([ 4.07741879, -3.17385777,  4.48131983]), rgb=array([68, 72, 35]), error=array(0.75840576), image_ids=array([2, 1]), point2D_idxs=array([53, 53])),
#  Point3D(id=54, xyz=array([ 4.13599626, -3.07077127,  4.26976682]), rgb=array([89, 90, 56]), error=array(0.99434059), image_ids=array([2, 1]), point2D_idxs=array([54, 54])),
#  Point3D(id=55, xyz=array([ 4.21194219, -2.98677318,  4.09253378]), rgb=array([63, 69, 13]), error=array(1.33394271), image_ids=array([  2,   1, 150]), point2D_idxs=array([  55,   55, 4043])),
#  Point3D(id=57, xyz=array([ 3.25582426, -1.88877103,  2.13215413]), rgb=array([81, 80, 39]), error=array(1.14329796), image_ids=array([2, 1]), point2D_idxs=array([57, 57])),
#  Point3D(id=287, xyz=array([ 4.43564694, -1.82060903,  3.26706601]), rgb=array([43, 44,  9]), error=array(0.74612107), image_ids=array([  2,   1, 150]), point2D_idxs=array([ 291,  291, 4191])),
#  Point3D(id=290, xyz=array([ 3.84225748, -1.14847752,  1.80449637]), rgb=array([79, 98, 42]), error=array(1.63590309), image_ids=array([  2,   1, 146, 145]), point2D_idxs=array([ 294,  294, 3432, 3155])),
#  Point3D(id=291, xyz=array([ 4.26255961, -1.20354966,  1.88205281]), rgb=array([ 88, 108,  66]), error=array(1.22598124), image_ids=array([ 2,  1, 90]), point2D_idxs=array([ 295,  295, 2904])),
#  Point3D(id=295, xyz=array([ 3.80452872, -1.17351118,  2.0118467 ]), rgb=array([78, 92, 40]), error=array(2.03613965), image_ids=array([  2,  90, 146, 148, 155, 156,   1,  89,   5, 198, 149, 199]), point2D_idxs=array([  299,   266,   168,   364,    76,   116,   299, 22753,    18,
#           180,   451,   278])),
#  Point3D(id=297, xyz=array([ 4.37228149, -1.13508567,  1.87121399]), rgb=array([66, 79, 42]), error=array(1.31269112), image_ids=array([ 2,  1,  3, 89, 90]), point2D_idxs=array([301, 301, 249, 160, 273])),
#  Point3D(id=298, xyz=array([ 4.58162251, -1.15708285,  1.90778149]), rgb=array([39, 46,  8]), error=array(0.62124193), image_ids=array([198,   1]), point2D_idxs=array([185, 302])),
#  Point3D(id=299, xyz=array([ 2.23842012, -1.98084983,  4.09474872]), rgb=array([38, 44, 12]), error=array(2.38868496), image_ids=array([ 3, 47, 48,  1,  2, 88]), point2D_idxs=array([236,  52, 102, 303, 303, 266])),
#  Point3D(id=301, xyz=array([ 2.44994104, -1.86278292,  3.78718236]), rgb=array([46, 64,  0]), error=array(1.63311773), image_ids=array([  3,  88, 149, 150,   1]), point2D_idxs=array([238, 258, 490, 592, 305])),
#  Point3D(id=302, xyz=array([ 2.59572897, -1.83999939,  3.71923027]), rgb=array([60, 78, 13]), error=array(1.6255182), image_ids=array([  2,  48,  89, 150,   1]), point2D_idxs=array([306,  91, 208, 593, 306])),
#  Point3D(id=303, xyz=array([ 2.7536247 , -1.84809943,  3.71573723]), rgb=array([60, 83,  0]), error=array(1.17382454), image_ids=array([ 88,  89,   1, 147]), point2D_idxs=array([ 227,  209,  307, 7491])),
#  Point3D(id=304, xyz=array([ 2.81661715, -1.74396241,  3.46412683]), rgb=array([59, 75, 15]), error=array(1.11834408), image_ids=array([  3, 149,   1]), point2D_idxs=array([241, 482, 308])),
#  Point3D(id=305, xyz=array([ 3.05254178, -1.79772132,  3.57361914]), rgb=array([106, 109,  65]), error=array(1.859882), image_ids=array([144, 149,  48, 150, 197]), point2D_idxs=array([  334,   483, 41414, 38372, 41150])),
#  Point3D(id=306, xyz=array([ 3.29090699, -1.86700179,  3.72280078]), rgb=array([54, 65, 12]), error=array(1.03871461), image_ids=array([ 48,  89, 149, 150,   1]), point2D_idxs=array([ 88, 212, 484, 586, 310])),
#  Point3D(id=372, xyz=array([ 4.06213095, -1.26110835,  2.6638201 ]), rgb=array([61, 64, 29]), error=array(2.7449951), image_ids=array([2, 1]), point2D_idxs=array([380, 380])),
#  Point3D(id=373, xyz=array([ 3.8886176 , -1.08722105,  2.26479042]), rgb=array([46, 49, 16]), error=array(0.3396712), image_ids=array([2, 1]), point2D_idxs=array([381, 381])),
#  Point3D(id=374, xyz=array([ 4.1571042 , -1.13469915,  2.364608  ]), rgb=array([49, 52, 22]), error=array(0.78188597), image_ids=array([2, 1]), point2D_idxs=array([382, 382])),
#  Point3D(id=375, xyz=array([ 4.32022135, -0.98985739,  2.00356448]), rgb=array([62, 79, 39]), error=array(2.00077056), image_ids=array([155,   1,   8, 107, 153, 157, 154]), point2D_idxs=array([   83,   383, 26403, 14055,  1849, 11899, 13898])),
#  Point3D(id=377, xyz=array([ 4.54507396, -0.95118439,  2.09738779]), rgb=array([48, 60, 16]), error=array(2.30897002), image_ids=array([  2, 107, 147, 149,   4, 104, 106, 150,  90]), point2D_idxs=array([  385,    12,   404,   549,  6439, 14699, 11949, 13629,   389])),
#  Point3D(id=379, xyz=array([ 2.96557123, -1.77719163,  4.3516437 ]), rgb=array([124, 119,  90]), error=array(0.88955523), image_ids=array([  2, 148]), point2D_idxs=array([387, 475])),
#  Point3D(id=381, xyz=array([ 3.29246667, -1.72591195,  4.1901872 ]), rgb=array([44, 53,  6]), error=array(1.64255774), image_ids=array([  2, 147, 149,  47]), point2D_idxs=array([  389,   409,   595, 35638])),
#  Point3D(id=382, xyz=array([ 3.49079647, -1.75162733,  4.24010503]), rgb=array([69, 71, 42]), error=array(1.23211917), image_ids=array([147, 148, 199,   1]), point2D_idxs=array([410, 470, 383, 390])),
#  Point3D(id=384, xyz=array([ 3.5926401 , -1.54652539,  3.70574201]), rgb=array([51, 68,  0]), error=array(1.63433374), image_ids=array([50, 87, 88,  1]), point2D_idxs=array([ 58, 113, 294, 392])),
#  Point3D(id=385, xyz=array([ 3.78033241, -1.54897991,  3.69215625]), rgb=array([74, 86, 44]), error=array(1.54926409), image_ids=array([ 88, 146, 149,   1, 147, 150]), point2D_idxs=array([  286,   286,   574,   393, 14433, 17220])),
#  Point3D(id=388, xyz=array([ 4.52114207, -1.53293301,  3.60585925]), rgb=array([45, 50, 17]), error=array(1.11037008), image_ids=array([  2,  49, 147]), point2D_idxs=array([396, 197, 400])),
#  Point3D(id=398, xyz=array([ 8.04354858, -8.03734461, 20.32328735]), rgb=array([138, 115,  72]), error=array(1.68829697), image_ids=array([ 2,  1,  3, 49,  4, 48]), point2D_idxs=array([ 409,  409, 2254, 3005,  775, 2388])),
#  Point3D(id=401, xyz=array([ 2.96895004, -1.71420108,  4.2846932 ]), rgb=array([43, 55, 14]), error=array(0.43154127), image_ids=array([2, 1]), point2D_idxs=array([412, 412])),
#  Point3D(id=402, xyz=array([ 2.9307347 , -1.56136495,  3.89167835]), rgb=array([55, 66, 11]), error=array(1.05309286), image_ids=array([ 2,  1, 48]), point2D_idxs=array([ 413,  413, 2400])),
#  Point3D(id=403, xyz=array([ 3.32798885, -1.71336618,  4.25985528]), rgb=array([39, 50,  4]), error=array(0.42403894), image_ids=array([2, 1]), point2D_idxs=array([414, 414])),
#  Point3D(id=404, xyz=array([ 3.17055602, -1.49319922,  3.69610072]), rgb=array([37, 46,  2]), error=array(0.6648117), image_ids=array([2, 1]), point2D_idxs=array([415, 415])),
#  Point3D(id=405, xyz=array([ 3.55402038, -1.62319147,  4.01017934]), rgb=array([89, 90, 63]), error=array(1.39023654), image_ids=array([  2,   1,   3, 150,  48,  88]), point2D_idxs=array([  416,   416,  2262,  4290, 12309, 11728])),
#  Point3D(id=406, xyz=array([ 3.42951771, -1.44201493,  3.54589863]), rgb=array([40, 50,  8]), error=array(1.24694266), image_ids=array([2, 1, 3]), point2D_idxs=array([ 417,  417, 2263])),
#  Point3D(id=413, xyz=array([ 4.56849993, -1.27512245,  3.05064114]), rgb=array([38, 42, 13]), error=array(0.23092154), image_ids=array([2, 1]), point2D_idxs=array([424, 424])),
#  Point3D(id=415, xyz=array([ 4.61123287, -0.88279922,  2.07008389]), rgb=array([39, 55, 10]), error=array(2.20475966), image_ids=array([ 10,   8, 103, 160, 106, 102,   6]), point2D_idxs=array([   22,  6965,  3096,  7081, 17406,  4211,  7200])),
#  Point3D(id=416, xyz=array([ 3.25502398, -1.521357  ,  4.09237124]), rgb=array([131, 134, 134]), error=array(2.49905079), image_ids=array([  2, 149]), point2D_idxs=array([427, 650])),
#  Point3D(id=418, xyz=array([ 3.63372618, -1.56899106,  4.20012359]), rgb=array([34, 50,  4]), error=array(2.23648418), image_ids=array([144, 146, 149,   1,  48,  49,  87, 150]), point2D_idxs=array([  499,   329,   625,   429,   214,   244,  9962, 12105])),
#  Point3D(id=419, xyz=array([ 3.57686537, -1.39306988,  3.72882572]), rgb=array([61, 74, 41]), error=array(1.60387478), image_ids=array([144,   1,   2,  88, 146]), point2D_idxs=array([493, 430, 430, 323, 330])),
#  Point3D(id=420, xyz=array([ 3.76749884, -1.40005541,  3.74166722]), rgb=array([112, 121,  85]), error=array(2.26044987), image_ids=array([ 87, 147,   1, 150]), point2D_idxs=array([138, 449, 431, 764])),
#  Point3D(id=421, xyz=array([ 3.85254288, -1.33573293,  3.55905731]), rgb=array([44, 62,  4]), error=array(1.58769057), image_ids=array([  2,  50, 150,   1]), point2D_idxs=array([432, 107, 765, 432])),
#  Point3D(id=422, xyz=array([ 4.14400032, -1.39945632,  3.72411588]), rgb=array([ 92, 102,  57]), error=array(1.16486826), image_ids=array([ 88,   1, 150]), point2D_idxs=array([305, 433, 766])),
#  Point3D(id=423, xyz=array([ 4.65662484, -1.35798527,  3.58940206]), rgb=array([37, 38,  8]), error=array(1.28576054), image_ids=array([ 88, 150,   1, 147]), point2D_idxs=array([295, 749, 434, 454])),
#  Point3D(id=424, xyz=array([ 4.66743457, -0.96772745,  2.54903873]), rgb=array([45, 55, 22]), error=array(1.26251208), image_ids=array([  2, 147,   1,  89]), point2D_idxs=array([435, 458, 435, 352])),
#  Point3D(id=425, xyz=array([ 4.50241088, -0.80995212,  2.11833128]), rgb=array([61, 70, 29]), error=array(1.92131341), image_ids=array([  2,   3,  90, 150,   1,  12]), point2D_idxs=array([436, 380, 432, 754, 436,  15])),
#  Point3D(id=426, xyz=array([ 4.48083029, -0.7292393 ,  1.93334072]), rgb=array([67, 82, 28]), error=array(1.96414833), image_ids=array([  2,  11, 154,  89,  90, 149, 198,  50,  51, 199, 109]), point2D_idxs=array([  437,    31,    86, 29998, 29164,   608,   393, 37101, 29223,
#           472,     9])),
#  Point3D(id=428, xyz=array([ 4.55632456, -1.38325203,  3.65935289]), rgb=array([76, 80, 51]), error=array(1.65743995), image_ids=array([145, 148, 149, 199]), point2D_idxs=array([352, 507, 603, 443])),
#  Point3D(id=429, xyz=array([ 4.79423108, -1.3453858 ,  3.53631067]), rgb=array([88, 89, 64]), error=array(1.00516861), image_ids=array([ 49, 146]), point2D_idxs=array([256, 316])),
#  Point3D(id=431, xyz=array([ 5.11239534, -1.2720302 ,  3.3618894 ]), rgb=array([36, 42, 15]), error=array(1.53906278), image_ids=array([  2, 150,   1]), point2D_idxs=array([442, 752, 442])),
#  Point3D(id=437, xyz=array([ 4.03117569, -4.69279209, 12.70667745]), rgb=array([ 94, 108,  50]), error=array(1.79541607), image_ids=array([2, 1]), point2D_idxs=array([449, 448])),
#  Point3D(id=439, xyz=array([ 7.38607567, -7.99208429, 21.40853925]), rgb=array([80, 92, 54]), error=array(3.401625), image_ids=array([2, 1]), point2D_idxs=array([451, 450])),
#  Point3D(id=441, xyz=array([ 0.39124603,  0.2801395 , -0.54060946]), rgb=array([ 99, 108, 124]), error=array(0.62662385), image_ids=array([2, 1]), point2D_idxs=array([453, 452])),
#  Point3D(id=442, xyz=array([ 0.43959716,  0.29395264, -0.58070012]), rgb=array([ 99, 110, 126]), error=array(0.72268169), image_ids=array([2, 1]), point2D_idxs=array([454, 453])),
#  Point3D(id=443, xyz=array([ 0.46944229,  0.31863046, -0.64984853]), rgb=array([ 99, 109, 126]), error=array(1.07746765), image_ids=array([2, 1]), point2D_idxs=array([455, 454])),
#  Point3D(id=445, xyz=array([ 3.49458561, -1.34275738,  3.6712357 ]), rgb=array([70, 79, 66]), error=array(2.59708636), image_ids=array([2, 1]), point2D_idxs=array([457, 456])),
#  Point3D(id=446, xyz=array([ 3.44175028, -1.20700936,  3.32270919]), rgb=array([78, 92, 67]), error=array(1.25185764), image_ids=array([ 2,  1, 50]), point2D_idxs=array([ 458,  457, 2408])),
#  Point3D(id=447, xyz=array([ 3.73775134, -1.28495615,  3.52476354]), rgb=array([ 93, 107,  65]), error=array(2.08136675), image_ids=array([ 1, 50]), point2D_idxs=array([  458, 18221])),
# ...
#  Point3D(id=3590, xyz=array([ 2.33711973, -2.15571389,  4.27465912]), rgb=array([ 99, 116,  56]), error=array(2.69057863), image_ids=array([4, 1]), point2D_idxs=array([  45, 3637])),
#  Point3D(id=3591, xyz=array([ 2.41803007, -2.10045864,  4.14455858]), rgb=array([27, 43,  0]), error=array(1.70782465), image_ids=array([4, 1, 2, 3]), point2D_idxs=array([  46, 3638, 5301, 4661])),
#  Point3D(id=3597, xyz=array([ 3.68482482, -1.84794427,  3.70207551]), rgb=array([43, 53,  6]), error=array(2.99106142), image_ids=array([4, 1]), point2D_idxs=array([  66, 3647])),
#  Point3D(id=3601, xyz=array([ 3.63666324, -1.10582202,  1.97485483]), rgb=array([56, 61, 26]), error=array(1.02547209), image_ids=array([89,  3, 49]), point2D_idxs=array([  193,  4690, 22411])),
#  Point3D(id=3604, xyz=array([ 4.64743603, -1.11399152,  1.85848096]), rgb=array([48, 55, 19]), error=array(2.12033755), image_ids=array([4, 1]), point2D_idxs=array([  73, 3654])),
#  Point3D(id=3606, xyz=array([ 4.57987696, -0.94431139,  1.73260868]), rgb=array([77, 93, 40]), error=array(2.26380324), image_ids=array([ 10, 150, 198, 199,   1,  89, 159, 151]), point2D_idxs=array([   8,  626,  249,  343, 3656,  215,   46,   80])),
#  Point3D(id=3613, xyz=array([ 4.17431887, -1.68053643,  3.60448697]), rgb=array([50, 59, 20]), error=array(2.71688825), image_ids=array([4, 1]), point2D_idxs=array([  92, 3664])),
#  Point3D(id=3632, xyz=array([ 3.77975239, -1.45845093,  3.46697492]), rgb=array([57, 68, 36]), error=array(0.81603392), image_ids=array([4, 1]), point2D_idxs=array([ 116, 3684])),
#  Point3D(id=3637, xyz=array([ 4.80449267, -1.37730581,  3.18684038]), rgb=array([35, 37, 14]), error=array(1.66224943), image_ids=array([152,   1, 150]), point2D_idxs=array([  60, 3689,  687])),
#  Point3D(id=3641, xyz=array([ 4.58091686, -0.81602574,  1.76087725]), rgb=array([54, 65, 17]), error=array(2.34425607), image_ids=array([  5,  10,  12,  90, 150, 152, 156, 198,   1,  50]), point2D_idxs=array([  66,   18,    7,  386,  692,   65,  153,  311, 3694,   13])),
#  Point3D(id=3643, xyz=array([ 4.59109935, -0.74797386,  1.59795545]), rgb=array([49, 54, 26]), error=array(1.50952633), image_ids=array([104, 152,  11]), point2D_idxs=array([17, 66, 21])),
#  Point3D(id=3645, xyz=array([ 3.3984108 , -1.49385821,  3.96209589]), rgb=array([72, 79, 66]), error=array(1.29555687), image_ids=array([4, 1]), point2D_idxs=array([ 144, 3698])),
#  Point3D(id=3647, xyz=array([ 3.51581042, -1.23711558,  3.25541176]), rgb=array([84, 91, 67]), error=array(0.52230396), image_ids=array([  2,   6, 143, 146]), point2D_idxs=array([12090, 10122, 25122, 12237])),
#  Point3D(id=3653, xyz=array([ 4.35826047, -0.61432646,  1.60790631]), rgb=array([85, 95, 56]), error=array(1.22476195), image_ids=array([4, 1]), point2D_idxs=array([ 158, 3708])),
#  Point3D(id=3656, xyz=array([ 0.07948496,  0.28405094, -0.40763673]), rgb=array([ 83,  92, 108]), error=array(2.07655747), image_ids=array([  4,   1,   3, 151]), point2D_idxs=array([ 166, 3711, 4778, 4287])),
#  Point3D(id=3663, xyz=array([ 0.00342468,  0.37773701, -0.37942517]), rgb=array([62, 70, 84]), error=array(0.56687405), image_ids=array([  4,   1, 151]), point2D_idxs=array([ 177, 3718, 4341])),
#  Point3D(id=3664, xyz=array([ 0.03657582,  0.39111165, -0.41839504]), rgb=array([63, 72, 87]), error=array(0.34598502), image_ids=array([  4,   1, 151]), point2D_idxs=array([ 178, 3719, 4342])),
#  Point3D(id=3670, xyz=array([ 0.05329759,  0.45926067, -0.4590771 ]), rgb=array([34, 39, 51]), error=array(2.55372717), image_ids=array([4, 1]), point2D_idxs=array([ 184, 3725])),
#  Point3D(id=3672, xyz=array([ 0.10811161,  0.48759516, -0.54518636]), rgb=array([65, 73, 89]), error=array(1.32941196), image_ids=array([4, 1]), point2D_idxs=array([ 186, 3727])),
#  Point3D(id=3678, xyz=array([ 0.04660865,  0.5084759 , -0.45202679]), rgb=array([106, 141, 147]), error=array(1.41774593), image_ids=array([4, 1]), point2D_idxs=array([ 196, 3733])),
#  Point3D(id=3681, xyz=array([ 0.12351536,  0.55098739, -0.58505371]), rgb=array([63, 72, 86]), error=array(0.85958872), image_ids=array([4, 1]), point2D_idxs=array([ 199, 3736])),
#  Point3D(id=3685, xyz=array([0.04881226, 0.42020788, 0.03430672]), rgb=array([168, 204, 226]), error=array(3.62139789), image_ids=array([4, 1]), point2D_idxs=array([ 207, 3740])),
#  Point3D(id=3686, xyz=array([ 0.1084989 ,  0.60245793, -0.58488489]), rgb=array([49, 60, 66]), error=array(1.63603829), image_ids=array([ 4,  1, 49]), point2D_idxs=array([ 210, 3741, 5008])),
#  Point3D(id=3694, xyz=array([ 0.05929825,  0.7219485 , -0.45751493]), rgb=array([58, 85, 83]), error=array(1.53335905), image_ids=array([  4,   1,  51, 151, 200, 150]), point2D_idxs=array([  227,  3750,  3986,   245, 23133, 31404])),
#  Point3D(id=3700, xyz=array([ 0.05981393,  0.80418144, -0.57659143]), rgb=array([ 83, 117, 116]), error=array(1.22508024), image_ids=array([  4,   1,  87,  88, 142, 151, 200]), point2D_idxs=array([ 238, 3756, 3961, 4708, 3863, 4474, 4996])),
#  Point3D(id=3701, xyz=array([ 0.09138718,  0.81649383, -0.61503118]), rgb=array([ 76, 108, 106]), error=array(1.84411035), image_ids=array([  4,   1, 150,  87, 149]), point2D_idxs=array([ 239, 3757, 6854, 3962, 6121])),
#  Point3D(id=3705, xyz=array([-0.08277402,  0.81640693, -0.46561721]), rgb=array([192, 211, 238]), error=array(1.58817857), image_ids=array([ 85,  45,  46,  47,  84, 140,  86, 195, 150,   2, 139,   4,  49,
#          94]), point2D_idxs=array([15500,  7199,  2207,  8233,  6015,  4028,   322,  8204,  9059,
#         15170,  4123,  7296,  8738,  6079])),
#  Point3D(id=3706, xyz=array([-0.01873531,  0.8327065 , -0.49980543]), rgb=array([185, 206, 237]), error=array(1.56574033), image_ids=array([4, 1]), point2D_idxs=array([ 248, 3762])),
#  Point3D(id=3710, xyz=array([ 0.12116366,  0.89202508, -0.70337721]), rgb=array([185, 203, 232]), error=array(1.13826035), image_ids=array([  4,   1,  94, 141]), point2D_idxs=array([ 252, 3766, 2769, 2918])),
#  Point3D(id=3713, xyz=array([ 0.22787679,  0.92310005, -0.80230073]), rgb=array([188, 205, 241]), error=array(2.13128808), image_ids=array([4, 1]), point2D_idxs=array([ 255, 3769])),
#  Point3D(id=3717, xyz=array([ 0.0109096 ,  0.9061991 , -0.59388397]), rgb=array([238, 241, 249]), error=array(1.54224732), image_ids=array([4, 1]), point2D_idxs=array([ 265, 3773])),
#  Point3D(id=3718, xyz=array([ 0.04095999,  0.92061067, -0.63333994]), rgb=array([230, 236, 249]), error=array(1.91409324), image_ids=array([  4,   1, 151]), point2D_idxs=array([ 266, 3774, 4515])),
#  Point3D(id=3719, xyz=array([ 0.08123301,  0.93009462, -0.66151044]), rgb=array([229, 234, 248]), error=array(0.69974988), image_ids=array([  4,   1, 151]), point2D_idxs=array([ 267, 3775, 4516])),
#  Point3D(id=3720, xyz=array([ 0.1025563 ,  0.94129388, -0.70618735]), rgb=array([226, 234, 248]), error=array(0.79015223), image_ids=array([  4,   1, 151]), point2D_idxs=array([ 268, 3776, 4517])),
#  Point3D(id=3721, xyz=array([ 0.11726383,  0.95232888, -0.70188765]), rgb=array([217, 230, 245]), error=array(1.55588031), image_ids=array([ 48,  47, 197]), point2D_idxs=array([  680, 10020, 12669])),
#  Point3D(id=3723, xyz=array([ 0.19333279,  0.98621053, -0.87148794]), rgb=array([225, 231, 244]), error=array(1.99942304), image_ids=array([ 4,  1, 51, 88]), point2D_idxs=array([ 271, 3779, 4039, 4740])),
#  Point3D(id=3724, xyz=array([-0.00630818,  0.9575256 , -0.5949511 ]), rgb=array([218, 227, 243]), error=array(1.68305001), image_ids=array([  4,   1, 151]), point2D_idxs=array([ 275, 3780, 4526])),
#  Point3D(id=3727, xyz=array([ 0.06985872,  0.98856397, -0.72045025]), rgb=array([213, 222, 238]), error=array(1.52880578), image_ids=array([  4,   1, 143]), point2D_idxs=array([ 279, 3783, 3844])),
#  Point3D(id=3728, xyz=array([ 0.09343736,  0.99807348, -0.74188993]), rgb=array([209, 217, 232]), error=array(2.45367725), image_ids=array([48, 49, 51, 88, 47]), point2D_idxs=array([22650, 22814, 18155,  2772, 24095])),
#  Point3D(id=3729, xyz=array([ 0.1295908 ,  1.01345356, -0.79240293]), rgb=array([217, 227, 243]), error=array(1.28803336), image_ids=array([  4,   1,  90, 142, 151]), point2D_idxs=array([ 282, 3785, 4700, 3882,  325])),
#  Point3D(id=3733, xyz=array([-0.05244862,  0.99712793, -0.55812299]), rgb=array([149, 152, 157]), error=array(1.38880197), image_ids=array([4, 1]), point2D_idxs=array([ 288, 3789])),
#  Point3D(id=3737, xyz=array([ 0.06490039,  1.04006029, -0.71273269]), rgb=array([150, 154, 160]), error=array(2.05421355), image_ids=array([  4,   1, 143, 147]), point2D_idxs=array([ 292, 3793, 3852, 4326])),
#  Point3D(id=3775, xyz=array([-0.00646722,  1.21949919, -0.59702907]), rgb=array([160, 167, 176]), error=array(1.53198305), image_ids=array([  4,   1,  50,  86, 151, 150]), point2D_idxs=array([ 357, 3831, 4429, 2611, 4622, 6924])),
#  Point3D(id=3776, xyz=array([ 0.02845548,  1.23024528, -0.63332738]), rgb=array([173, 178, 185]), error=array(2.19788972), image_ids=array([  4,   1,   2,  93, 151]), point2D_idxs=array([ 359, 3832, 5610, 3062, 4623])),
#  Point3D(id=3778, xyz=array([ 0.10708161,  1.25833316, -0.75584518]), rgb=array([179, 190, 202]), error=array(1.47696977), image_ids=array([  4,   1,  47, 150, 151]), point2D_idxs=array([ 362, 3834, 4830, 6928, 4626])),
#  Point3D(id=3782, xyz=array([-0.08551052,  1.25011254, -0.46739874]), rgb=array([148, 151, 159]), error=array(1.71566533), image_ids=array([151,   3,   4, 146, 150]), point2D_idxs=array([  435, 30820, 19080, 32893, 31481])),
#  Point3D(id=3788, xyz=array([ 0.09048708,  1.30602759, -0.7577176 ]), rgb=array([179, 187, 200]), error=array(2.58737787), image_ids=array([  4,   1,  90, 143, 147, 195,  93,   3,  89,  94, 150,   2, 142]), point2D_idxs=array([  375,  3844,  4754,  3887,  4347,  3899,   547, 23563, 20908,
#         11586,  6939, 11058,  8272])),
#  Point3D(id=3801, xyz=array([ 0.12382814,  1.36747589, -0.78096678]), rgb=array([156, 160, 167]), error=array(1.14109785), image_ids=array([ 4,  1,  2, 89]), point2D_idxs=array([ 395, 3857, 5664, 4783])),
#  Point3D(id=3809, xyz=array([ 0.01305441,  1.38312628, -0.61478233]), rgb=array([161, 170, 181]), error=array(2.11746132), image_ids=array([142,   3,  50,  88, 140, 148, 143, 149, 197,   2,  51, 150,  48,
#          49, 151]), point2D_idxs=array([  851,  5173, 29646, 27617, 15239, 17382,  3902,  6246,  4961,
#         28419, 25021,  7282,  4806,  5118,  4713])),
#  Point3D(id=3822, xyz=array([ 0.15307633,  1.47270849, -0.67617578]), rgb=array([4, 5, 9]), error=array(1.61466852), image_ids=array([  4,   1,   3,  49,  92, 200, 146]), point2D_idxs=array([ 433, 3878, 5205, 5131, 3040, 5175, 5148])),
#  Point3D(id=3824, xyz=array([-0.13796056,  1.4404322 , -0.29338852]), rgb=array([205, 213, 225]), error=array(1.88644776), image_ids=array([  4, 153,   3,   2,  94, 151]), point2D_idxs=array([ 442,  136, 5228, 5728, 3008, 4784])),
#  Point3D(id=3835, xyz=array([-0.16383701,  1.4948224 , -0.26119011]), rgb=array([145, 152, 160]), error=array(2.54078048), image_ids=array([151,   2,  49,  88,  89,  90, 150,   3,  51]), point2D_idxs=array([  535, 25250, 28623, 20425, 21119, 26531, 31536, 30893,  8547])),
#  Point3D(id=3861, xyz=array([ 0.18236809,  1.69978475, -0.60433426]), rgb=array([135, 136, 138]), error=array(2.41503651), image_ids=array([  4,   1,   3,  88,  91, 147, 151,  48, 148, 145]), point2D_idxs=array([ 496, 3917, 5322, 4929, 3467, 4389, 4901, 4900, 5265, 4143])),
#  Point3D(id=3865, xyz=array([-0.13941193,  1.67368595, -0.14792652]), rgb=array([110, 114, 116]), error=array(1.96620672), image_ids=array([  4,   1, 150,   3]), point2D_idxs=array([ 505, 3921, 7019, 5341])),
#  Point3D(id=3869, xyz=array([ 0.21508188,  1.75099457, -0.65296316]), rgb=array([58, 58, 58]), error=array(2.32590311), image_ids=array([  2,  47, 145, 147, 196, 200, 146, 197]), point2D_idxs=array([23397, 20537, 14982, 13290, 21646, 14857, 16582, 21466])),
#  Point3D(id=3898, xyz=array([ 2.38848774, -1.99673186,  3.81183791]), rgb=array([59, 75, 36]), error=array(1.45099507), image_ids=array([  5,   2,   6, 152, 153]), point2D_idxs=array([  14, 6336,  236, 3185, 1774])),
#  Point3D(id=3907, xyz=array([ 4.6918795 , -1.83306199,  3.55953665]), rgb=array([55, 61, 11]), error=array(0.38218243), image_ids=array([5, 1]), point2D_idxs=array([  31, 3971])),
#  Point3D(id=3908, xyz=array([ 4.13142224, -1.06968607,  1.99802365]), rgb=array([46, 54, 18]), error=array(0.52655031), image_ids=array([90,  2]), point2D_idxs=array([  325, 22594])),
#  Point3D(id=3909, xyz=array([ 4.25728471, -1.0373529 ,  1.88327696]), rgb=array([56, 72, 28]), error=array(2.09302908), image_ids=array([  5,   1, 154, 155, 156]), point2D_idxs=array([  33, 3973, 1377, 1195, 1176])),
#  Point3D(id=3910, xyz=array([ 4.72496209, -1.01414207,  1.81187235]), rgb=array([ 98, 117,  63]), error=array(1.2662577), image_ids=array([  5,   1, 155]), point2D_idxs=array([  34, 3974, 1197])),
#  Point3D(id=3918, xyz=array([ 4.42280433, -1.14293108,  2.39009148]), rgb=array([60, 71, 32]), error=array(2.57370531), image_ids=array([  5,   1, 156]), point2D_idxs=array([  53, 3984, 1206])),
#  Point3D(id=3919, xyz=array([ 4.31962236, -1.0563863 ,  2.20261689]), rgb=array([78, 86, 51]), error=array(1.95164307), image_ids=array([  5,   1, 153, 154, 155, 156]), point2D_idxs=array([  54, 3985, 1855, 1405, 1228, 1207])),
#  ...]

# %%
points = read_points3D_binary("/home/roman/ba/huk_scenes_stablenormal/audi_silver/sparse/0/points3D.bin")

# %%
write_ply_ascii(points, "/home/roman/ba/huk_scenes_stablenormal/audi_silver/sparse/0/points3D.ply")

# %%
q_wxyz
# Out:
# array([ 0.84226826,  0.5390325 ,  0.0053049 , -0.        ])

# %%
R = o3d.geometry.get_rotation_matrix_from_quaternion(q_wxyz)

pcd.rotate(R, center=pcd.get_center())

# %%
# [-0.00211864  0.93661683  0.350349   -1.68627746]
# [-0.0089363   0.90801993  0.41883165 -1.77691084]

# %%
ref_env = o3d.io.read_point_cloud("/home/roman/ba/datasets/ref_real/sedan/envs/points3D.ply")

# %%
env_data = np.asarray(ref_env.points)

# %%
density = env_data.shape[0] / (env_data.max(axis=0) - env_data.min(axis=0)).prod()

# %%
density
# Out:
# np.float64(4.160198365056736)

# %%
# env_bounds: [[-15.41093584, -9.52983853, -26.35259539], [28.42411913, 10.86091045, 17.71185112]]
